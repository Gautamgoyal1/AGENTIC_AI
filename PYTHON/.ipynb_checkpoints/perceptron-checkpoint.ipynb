# %%
print("Enter the value: ")
x1 = int(input())
x2 = 0

w1 = 0.5
w2 = 0.5

bias = -0.7

z = x1 * w1 + x2 * w2 + bias

if z >= 0.4:
    output = 1
else:
    output = 0

print(output)
# Out:
# Enter the value:
#  5
# 1

# %% [markdown]
# ## Perceptron Class

# %%
# Simple perceptron for AND gate

class Perceptron:
    def __init__(self, learning_rate=0.1, epochs=10):
        self.lr = learning_rate
        self.epochs = epochs
        self.weights = [0.21, 0.21]
        self.bias = 0

    def activation(self, z):
        if z >= 0:
            return 1
        return 0
    def activation1(self,z):
        output = 1/(1+np.exp(-z))
        return output
    def predict(self, inputs):
        z = 0
        for i in range(len(inputs)):
            z += inputs[i] * self.weights[i]
        z += self.bias
        return self.activation1(z)

    def train(self, X, y):
        for _ in range(self.epochs):
            for i in range(len(X)):
                prediction = self.predict(X[i])
                error = y[i] - prediction

                # Update weights
                for j in range(len(self.weights)):
                    self.weights[j] += self.lr * error * X[i][j]
                    print(f"Updated weights: {self.weights}")

                # Update bias
                self.bias += self.lr * error


X = [
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
]

y = [0, 0, 0, 1]

p = Perceptron()
p.train(X, y)

print(p.predict([1, 1]))  # 1
print(p.predict([1, 0]))  # 0
# Out:
# Updated weights: [np.float64(0.21), 0.21]:.4f
# Updated weights: [np.float64(0.21), np.float64(0.21)]:.4f
# Updated weights: [np.float64(0.21), np.float64(0.21)]:.4f
# Updated weights: [np.float64(0.21), np.float64(0.15600851154444342)]:.4f
# Updated weights: [np.float64(0.157352266306572), np.float64(0.15600851154444342)]:.4f
# Updated weights: [np.float64(0.157352266306572), np.float64(0.15600851154444342)]:.4f
# Updated weights: [np.float64(0.20344222722278002), np.float64(0.15600851154444342)]:.4f
# Updated weights: [np.float64(0.20344222722278002), np.float64(0.20209847246065143)]:.4f
# Updated weights: [np.float64(0.20344222722278002), np.float64(0.20209847246065143)]:.4f
# Updated weights: [np.float64(0.20344222722278002), np.float64(0.20209847246065143)]:.4f
# Updated weights: [np.float64(0.20344222722278002), np.float64(0.20209847246065143)]:.4f
# Updated weights: [np.float64(0.20344222722278002), np.float64(0.1509909003825437)]:.4f
# Updated weights: [np.float64(0.15357856902944916), np.float64(0.1509909003825437)]:.4f
# Updated weights: [np.float64(0.15357856902944916), np.float64(0.1509909003825437)]:.4f
# Updated weights: [np.float64(0.20243352181174412), np.float64(0.1509909003825437)]:.4f
# Updated weights: [np.float64(0.20243352181174412), np.float64(0.19984585316483866)]:.4f
# Updated weights: [np.float64(0.20243352181174412), np.float64(0.19984585316483866)]:.4f
# Updated weights: [np.float64(0.20243352181174412), np.float64(0.19984585316483866)]:.4f
# Updated weights: [np.float64(0.20243352181174412), np.float64(0.19984585316483866)]:.4f
# Updated weights: [np.float64(0.20243352181174412), np.float64(0.1512162681700872)]:.4f
# Updated weights: [np.float64(0.25304585260043344), np.float64(0.18906513175452475)]:.4f
# Updated weights: [np.float64(0.25304585260043344), np.float64(0.24549723741199023)]:.4f
# Updated weights: [np.float64(0.25304585260043344), np.float64(0.24549723741199023)]:.4f
# Updated weights: [np.float64(0.25304585260043344), np.float64(0.24549723741199023)]:.4f
# Updated weights: [np.float64(0.25304585260043344), np.float64(0.24549723741199023)]:.4f
# Updated weights: [np.float64(0.25304585260043344), np.float64(0.20484058306767974)]:.4f
# Updated weights: [np.float64(0.21318546065288313), np.float64(0.20484058306767974)]:.4f
# Updated weights: [np.float64(0.21318546065288313), np.float64(0.20484058306767974)]:.4f
# Updated weights: [np.float64(0.2702911784534258), np.float64(0.20484058306767974)]:.4f
# Updated weights: [np.float64(0.2702911784534258), np.float64(0.2619463008682224)]:.4f
# Updated weights: [np.float64(0.2702911784534258), np.float64(0.2619463008682224)]:.4f
# Updated weights: [np.float64(0.2702911784534258), np.float64(0.2619463008682224)]:.4f
# Updated weights: [np.float64(0.2702911784534258), np.float64(0.2619463008682224)]:.4f
# Updated weights: [np.float64(0.2702911784534258), np.float64(0.22228276567505212)]:.4f
# Updated weights: [np.float64(0.2313746687005691), np.float64(0.22228276567505212)]:.4f
# Updated weights: [np.float64(0.2313746687005691), np.float64(0.22228276567505212)]:.4f
# Updated weights: [np.float64(0.28897464656127136), np.float64(0.22228276567505212)]:.4f
# Updated weights: [np.float64(0.28897464656127136), np.float64(0.2798827435357544)]:.4f
# Updated weights: [np.float64(0.28897464656127136), np.float64(0.2798827435357544)]:.4f
# Updated weights: [np.float64(0.28897464656127136), np.float64(0.2798827435357544)]:.4f
# Updated weights: [np.float64(0.28897464656127136), np.float64(0.2798827435357544)]:.4f
# Updated weights: [np.float64(0.28897464656127136), np.float64(0.24108151875185166)]:.4f
# Updated weights: [np.float64(0.2508765046717662), np.float64(0.24108151875185166)]:.4f
# Updated weights: [np.float64(0.2508765046717662), np.float64(0.24108151875185166)]:.4f
# Updated weights: [np.float64(0.308821101397249), np.float64(0.24108151875185166)]:.4f
# Updated weights: [np.float64(0.308821101397249), np.float64(0.29902611547733443)]:.4f
# 0.46339917086708865
# 0.390385571836604

# %%
import numpy as np

inputs = [-1.5,2.0,0.5]
weights = [0.5,-0.3,0.8]

bias = 0.1
weighted_sum = sum(i * w for i,w in zip(inputs,weights)) + bias

output = 1 if weighted_sum>=0 else 0
print(f"weighted sum: {weighted_sum:.4f}")
print(f"Output: {output}")
# Out:
# weighted sum: -0.8500
# Output: 0

# %% [markdown]
# ## Perceptron using SIGMOID Function

# %%
import numpy as np

x = np.array([1, 0])
w = np.array([0.5, 0.3])

b = -0.2
z = np.dot(x, w) + b

# sigmoid
output = 1 / (1 + np.exp(-z))

print(output)
# Out:
# 0.574442516811659
